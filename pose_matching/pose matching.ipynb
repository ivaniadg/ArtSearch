# %% [markdown]
# # Pose matching using openpose

# %% [markdown]
# ## Importing libraries (and openpose linux)

# %%
import sys
import cv2
import numpy as np
import argparse
import pandas as pd
import math
import copy
import time
import pickle
from itertools import zip_longest
from scipy import spatial
import matplotlib.pyplot as plt
sys.path.append('../../python')
from openpose import pyopenpose as op

# %% [markdown]
# ## Set flags and parameters

# %%
# Flags
parser = argparse.ArgumentParser()
parser.add_argument("--image_dir", default="/home/mortirreke/Desktop/assets", help="Process an image. Read all standard formats (jpg, png, bmp, etc.).")
args = parser.parse_known_args()


# Custom Params (refer to include/openpose/flags.hpp for more parameters)
params = dict()
params["model_folder"] = "../../../models/"
params["net_resolution"] = "320x320"
#params["write_json"] = "/home/mortirreke/Desktop/output/"

# Function for grouping list items
def grouper(iterable, n, fillvalue=None):
    "Collect data into fixed-length chunks or blocks"
    args = [iter(iterable)] * n
    return list(zip_longest(*args, fillvalue=fillvalue))

# Get body parts and pose pairs from openpose library (refer to openpose/src/openpose/pose/poseParameters.cpp for more parameters)
BODY_PARTS = op.getPoseBodyPartMapping(op.BODY_25)
POSE_PAIRS = op.getPosePartPairs(op.BODY_25)
POSE_PAIRS = grouper(POSE_PAIRS, 2, None)


for i in range(0, len(args[1])):
    curr_item = args[1][i]
    if i != len(args[1])-1: next_item = args[1][i+1]
    else: next_item = "1"
    if "--" in curr_item and "--" in next_item:
        key = curr_item.replace('-','')
        if key not in params:  params[key] = "1"
    elif "--" in curr_item and "--" not in next_item:
        key = curr_item.replace('-','')
        if key not in params: params[key] = next_item

# %% [markdown]
# ## extract keypoints from images in a folder

# %%
# Starting OpenPose
opWrapper = op.WrapperPython()
opWrapper.configure(params)
opWrapper.start()
imagePaths = op.get_images_on_directory(args[0].image_dir)

# Process Image

datum_list = []

for i, image in enumerate(imagePaths):
    # if(i == 100):
    #     break
    datum = op.Datum()
    imageToProcess = cv2.imread(image)
    datum.cvInputData = imageToProcess
    opWrapper.emplaceAndPop(op.VectorDatum([datum]))
    network_output = datum.poseKeypoints
    datum_list.append([image, network_output])
    time.sleep(0.1)

df = pd.DataFrame(datum_list, columns=['image_path', 'keypoints'])
np.set_printoptions(linewidth=100000)
# Out:
# Starting OpenPose Python Wrapper...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.

# %% [markdown]
# ## Extracting coordinates from output + cleaning

# %%
keypoints = [] #list with all detected poses (coordinates) and their respective file
for index,row in df.iterrows():
  network_output = row[1]
  # Unwrapping Person Keypoints from Openpose Network Output
  index_names = copy.deepcopy(BODY_PARTS)
  index_names.pop(25)
  if network_output is not None:
      count = 0
      for human in network_output:
          count += 1
          output_sub_arr = {}
          for i in range(len(human)):
              output_sub_arr[BODY_PARTS[i]]= [int(human[i][0]),int(human[i][1]), row[0]]
          print("\n   Person Detected")
          dataframe = pd.DataFrame(output_sub_arr.values(), columns=['x','y','path'], index=list(index_names.values()))
          keypoints.append(dataframe)
  else:
      print("no keypoints detected for :" + row[0])
# Out:
# no keypoints detected for :/home/mortirreke/Desktop/assets/011.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/albert-pinkham-ryder_a-country-girl-1905.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/albrecht-altdorfer_wild-folk-family-1510.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/albrecht-durer_birth-of-christ.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/aleksandra-ekster_costume-design-for-modern-khlestakov-1921.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/aleksandra-ekster_costume-design-for-salome-1917.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/aleksandra-ekster_don-juan-and-death-sheet-of-from-the-album-theater-set-1930.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/aleksandra-ekster_romeo-and-juliet-costume-for-first-mask-at-ball-1921.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/alexander-ivanov_exit-from-the-last-supper.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/alexander-ivanov_moses-doubted-god-s-promise-to-satisfy-people-with-meat.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/alexander-ivanov_the-prophet-elijah-and-the-widow-sareptana.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/alfred-sisley_the-straw-rent-1888.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/alfred-sisley_view-of-montmartre-from-the-cite-des-fleurs-1869.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/allen-jones_pour-les-levres-1965.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/andr-lhote_nature-morte-au-chinois-1930.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/andre-masson_card-trick.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/andre-masson_reclining-nude-1956.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/andy-warhol_jackie-1.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/aristarkh-lentulov_tverskoi-boulevard-1917.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/asano-takeji_tojinbo-1949-shin.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/aubrey-beardsley_cinesias-entreating-myrrhina-to-coition.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/aubrey-beardsley_how-queen-guenever-made-her-a-nun-1894.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/barbara-kruger_untitled-not-stupid-enough.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/bracha-l-ettinger_eurydice-n-5-1994.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/carl-spitzweg_women-s-bath-in-dieppe.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/charles-bell_before-the-journey-1986.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/charles-bell_buck-rogers-1972.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/charles-bell_finis-coronat-opus-1995.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/charles-bell_miami-beach-1989.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/charles-bell_oh-boy-1990.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/charles-bell_sophisticated-lady-1993.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/charles-francois-daubigny_the-harvest-1851.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/charles-lapicque_ezechiel-mesurant-le-temple-1973.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/claude-lorrain_landscape-with-aeneas-at-delos-1672.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/claude-lorrain_landscape-with-flight-into-egypt-1663.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/claude-lorrain_landscape-with-rest-in-flight-to-egypt-1666.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/david-alfaro-siqueiros_the-march-of-humanity-1971-1.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/david-burliuk_at-the-siberian-village-1931.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/david-burliuk_japan-and-america-1921.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/david-burliuk_three-woman-1930.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/david-burliuk_untitled-view-of-village-from-all-sides.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/diego-rivera_a-history-of-medicine-1953.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/diego-rivera_creation-1923.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/diego-rivera_sugar-plantation-tealtenango-morelos-and-indian-slaves-in-the-gold-mines.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/diego-rivera_the-sugar-mill-1923.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/edgar-degas_seated-woman-combing-her-hair.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/el-lissitzky_flying-sun-1916.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/emile-bernard_young-woman-in-kimono-reading-1887.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/ernst-fuchs_crucifixion-and-self-portrait-with-inge-beside-the-cross.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/ernst-fuchs_job-and-the-judgement-of-paris-1966.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/ernst-fuchs_the-divine-jerusalem-1995.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/erte_ebony-1.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/erte_evening-creation.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/erte_number-8.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/erte_opium-mah-jongg.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/erte_swept-away.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/erte_the-aces-hearts.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/erte_the-seven-deadly-sins-pride.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/erte_top-hats.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/erte_winter-s-arrival.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/eugene-boudin_the-shore-at-tourgeville-1893.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/eyvind-earle_mother-child-1975.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/felix-vallotton_still-life-with-blue-trim-1922.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/ferdinand-georg-waldm-ller_lime-kiln-in-the-hinterbr-hl-1845.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/ferdinand-georg-waldm-ller_the-birthday-table-1840-1.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/fernand-leger_creation-of-the-world-1924.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/fernando-botero_weeping-woman.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/Fondo-de-pantalla-Manga-2.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/fornasetti_theme-variation-decorative-plate-091-veil.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/fornasetti_theme-variation-decorative-plate-122-clown.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/fornasetti_theme-variation-plate-1.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/fornasetti_theme-variations-decorative-plate-39-crescent-moon.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/fornasetti_theme-variations-decorative-plate-45-checkerboard.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/fornasetti_theme-variations-decorative-plate-77-crying-face.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/fornasetti_theme-variations-decorative-plate-334-woman-with-finger-on-lips.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/fornasetti_theme-variations-plate-96-butterfly.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/fornasetti_theme-variations-plate-206.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/franz-marc_in-the-rain-1912.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/FreeGreatPicture.com-21660-cartoon-childhood-dream.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/Genshiken_-_anime_screenshot.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/george-inness_summer-landscape-1894.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/george-inness_tenafly-autumn-1891.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/george-inness_the-lackawanna-valley-1855.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/george-segal_the-bus-driver-1962.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/giacomo-balla_a-worker-s-day-1904.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/giorgio-de-chirico_gladiators-1.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/giorgio-de-chirico_the-battle-of-lapiths-and-centaurs.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/giorgio-de-chirico_the-poet-s-farewell-1923.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/giotto_envy-1306.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/giotto_the-dream-of-innocent-iii-1299.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/giovanni-boldini_nude-of-young-lady-on-couch.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/glennray-tutor_solo-i-dreamed-it-all-2006.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/hasui-kawase_lake-matsubara-in-the-morning-shinsu-1941.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/hasui-kawase_snow-at-shiba-park-1931.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/helene-schjerfbeck_girl-reading-1904.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/helene-schjerfbeck_portrait-of-a-girl-1887.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/henri-de-toulouse-lautrec_they-woman-with-a-tub-1896.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/henri-martin_church-in-labastide-du-vert.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/henri-martin_fishing-boats-at-collioure-1895.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/henri-martin_fountain-of-the-versailles-queen-1920.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/henri-martin_port-collioure.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/henri-martin_port-of-marseille-3.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/henri-martin_the-green-bridge.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/henri-martin_the-pergola-in-marquayrol.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/henrique-pousao_senhora-vestida-de-negro-1882.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/heorhiy-narbut_illustration-to-wooden-eagle-1909.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/hiro-yamagata_telephone-1987.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/hiroshi-yoshida_arashiyama-1935.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/hiroshi-yoshida_ghat-in-benares-1931.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/hiroshi-yoshida_in-the-botanical-garden-1926.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_16.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_22.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_36.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_52.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_62.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_65.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_67.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_85.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_121.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_130.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_133.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_144.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_157.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_158.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_186.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_189.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_192.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_197.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_207.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_211.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_215.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_238.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_253.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_259.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_265.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_271.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_279.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_296.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_307.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_318.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_319.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_329.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_331.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_336.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_340.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_353.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_355.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_361.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_365.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_379.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_388.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_391.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_412.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_419.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_428.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_449.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_450.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_465.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_467.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_500.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_501.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_540.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_550.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_579.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_580.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_588.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_598.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_626.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_644.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_669.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_673.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_686.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_706.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_711.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_724.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_726.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_746.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_762.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_765.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_782.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_803.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_817.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_823.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_829.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_838.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_843.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_852.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_873.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_874.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_900.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_910.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_914.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_933.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_939.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_941.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_943.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_944.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_959.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_965.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_988.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_993.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1002.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1016.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1043.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1056.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1059.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1071.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1073.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1078.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1083.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1086.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1094.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1095.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1100.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1102.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1122.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1126.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1161.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1163.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1186.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1193.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1198.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1207.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1242.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1259.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1260.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1273.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1277.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1284.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1286.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1287.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1292.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1294.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1303.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1317.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/images_1318.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# ...
# no keypoints detected for :/home/mortirreke/Desktop/assets/nicolas-poussin_bacchanal-of-putti-1626.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/odilon-redon_flower-clouds-1903.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/odilon-redon_temptation.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/odilon-redon_the-wheel-of-fortune.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/oleksandr-bogomazov_electrician-1915.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/oleksandr-bogomazov_self-portrait.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/oleksandr-bogomazov_tram-1914.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/olga-rozanova_smythy.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/pablo-picasso_bust-of-young-woman-from-avignon-1907.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/patrick-procktor_departure-from-invitation-to-a-voyage-portfolio-of-5-aquatints-1969.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/patrick-procktor_ossie-gervase-and-eric-from-invitation-to-a-voyage-portfolio-of-5-aquatints-1969.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/paul-cezanne_large-bathers-1900.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/paul-du-toit_cosmic-attraction-2011.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/paul-du-toit_good-bad-ugly.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/paul-du-toit_thrill-2007.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/paul-du-toit_transparency-2003.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/paul-du-toit_untitled-2010-4.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/paul-du-toit_untitled-2010-5.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/paul-gauguin_still-life-with-onions-beetroot-and-japanese-print-1889.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/paul-jacoulet_le-billet-doux-mongole-1955.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/paul-serusier_breton-woman-going-to-the-washing-place-1890.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/paul-serusier_breton-women-the-meeting-in-the-sacred-grove.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/paul-serusier_mother-and-child-on-a-breton-landscape-1890.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/paul-serusier_shepherd-in-the-valley-of-chateauneuf-1917.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/paul-serusier_the-flock-in-the-black-forest-1903.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/paul-serusier_the-wash-in-a-large-meadow-1894.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/paul-wunderlich_woman-with-fur.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_a-couple-1912.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_a-man-in-the-world-1925.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_execution-1912.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_faces-1940.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_formula-of-the-petrograd-proletariat-1920-21.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_head-1923.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_heads-1924.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_horsemen-1911.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_magi-wise-men-1914.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_selfportrait-1911.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_the-head.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_the-hog-1913.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_the-kolkhoznik-member-of-a-collective-farm-1931.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_two-men-1938.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_untitled-heads-a-boot-a-fish.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_untitled-three-figures-1913.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/pavel-filonov_war-with-germany-1915.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/peter-max_illustration-1970.jpg
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/pierre-bonnard_the-mediterranean-triptych-1.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/pierre-bonnard_woman-in-a-blue-pelerine-1898.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/pyotr-konchalovsky_portrait-of-a-violinist-grigory-fedorovich-romashkov-1918-1.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/raphael-kirchner_mikado-1900-5.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/raphael-kirchner_pierrot-s-love.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/richard-lindner_42nd-street.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/richard-lindner_double-portrait.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/richard-lindner_solitaire.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/richard-lindner_thank-you.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/richard-lindner_the-ace-of-clubs-1973.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/richard-lindner_the-child-s-dream.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/robert-williams_ranch-of-disease-1993.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/school_hair_cartoon.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/sigmar-polke_animal-in-blue-1983.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/sigmar-polke_girlfriends-i-1967.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/simpsonsintronew.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/southparkboys_medium.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/sue-coe_trouble-war.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/theo-van-doesburg_banister-post-huis-de-lange-alkmaar.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/theodore-rousseau_not_detected_198922.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/tsuguharu-foujita_la-vierge-et-l-enfant.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/tsukioka-yoshitoshi_a-young-woman-from-kansei-period-playing-with-her-cat.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/tsukioka-yoshitoshi_songoku-the-monkey-king-and-the-jewelled-hare-by-the-moon-1891.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/umberto-boccioni_the-morning-1909.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/unnamed.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/utagawa-kunisada_ichikawa-danjuro-vii-wielding-an-axe-wearing-a-white-haired-wig.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/utagawa-kuniyoshi_benkei-holdin-a-halberd.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/utagawa-kuniyoshi_tamomori-tied-to-a-huge-anchor-ready-to-cast-himself-into-the-sea.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/utagawa-kuniyoshi_toki-jurozaemon-mitsuchika.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/utagawa-kuniyoshi_women-24.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/utagawa-sadatora_oguri-hangan-sukeshige-in-battle.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/vasily-vereshchagin_china-tent-1870.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/victor-brauner_head-and-two-boxers-1929.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/vincent-van-gogh_girl-in-white-in-the-woods-1882.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/vincent-van-gogh_japonaiserie-oiran-after-kesai-eisen-1887.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/vincent-van-gogh_park-with-figures.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/vincent-van-gogh_the-langlois-bridge-at-arles-1888-2.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/vincent-van-gogh_the-langlois-bridge-at-arles-with-women-washing-1888.jpg
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/vladimir-tatlin_sketch-for-stage-set-glinka-s-ivan-susanin-1914.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/walter-battiss_horse-and-butterfly.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/willem-van-genk_parnasky-culture-1972.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/willi-baumeister_swimmers-on-the-ladder-1929.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/wojciech-siudmak_behind-the-mirror.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/wojciech-siudmak_golden-cavalier.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/wojciech-siudmak_metamorphosis-1.jpg
# no keypoints detected for :/home/mortirreke/Desktop/assets/wojciech-siudmak_morning-poem.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
# no keypoints detected for :/home/mortirreke/Desktop/assets/yamamura-toyonari_matsumoto-koshiro-vii-as-sekibei-1919.jpg
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected
#
#    Person Detected

# %% [markdown]
# ### save and load output (optional)

# %%
# with open('/home/mortirreke/Desktop/output/keypointsall.pickle', 'wb') as handle:
#     pickle.dump(keypoints, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('/home/mortirreke/Desktop/output/keypointsall.pickle', 'rb') as handle:
    keypoints = pickle.load(handle)

# %% [markdown]
# ## Check if coordinates work

# %%
for pose in keypoints:
    test = cv2.imread(pose.iloc[0]['path'])
    for i,keypoint in pose.iterrows():
        x = keypoint["x"]
        y = keypoint["y"]
        test = cv2.circle(test, (x,y), 1, (0,0,255), -1)
    cv2.imshow("keypoints",test)
    key = cv2.waitKey(0)
    if key == 27: break
    cv2.destroyAllWindows()

# %% [markdown]
# # Pose Matching

# %% [markdown]
# ## Compare similarity

# %%
def similarity_score(pose1:pd.DataFrame, pose2:pd.DataFrame):
    p1 = []
    p2 = []

    # Remove keypoints when keypoint values is none
    pose1_df = pd.DataFrame(pose1, columns=['x','y'])
    pose2_df = pd.DataFrame(pose2, columns=['x','y'])
    # pose_df = pd.concat([pose1, pose2],axis = 1).dropna().reset_index(drop=True)
    # pose1_df = pose1.rename({'x':})
    # pose2_df = pose_df[['Xp2','Yp2']]

    pose1 = pose1_df.to_numpy()
    pose2 = pose2_df.to_numpy()

    pose_1 = np.array(pose1, dtype=float)
    pose_2 = np.array(pose2, dtype=float)

    # Normalize coordinates
    pose_1[:,0] = pose_1[:,0] / max(pose_1[:,0])
    pose_1[:,1] = pose_1[:,1] / max(pose_1[:,1])
    pose_2[:,0] = pose_2[:,0] / max(pose_2[:,0])
    pose_2[:,1] = pose_2[:,1] / max(pose_2[:,1])

    # Turn (16x2) into (32x1)
    for joint in range(pose_1.shape[0]):
        x1 = pose_1[joint][0]
        y1 = pose_1[joint][1]
        x2 = pose_2[joint][0]
        y2 = pose_2[joint][1]

        p1.append(x1)
        p1.append(y1)
        p2.append(x2)
        p2.append(y2)

    p1 = np.array(p1)
    p2 = np.array(p2)


    # Looking to minimize the distance if there is a match
    # Computing two different distance metrics
    cosineDistance = spatial.distance.cosine(p1, p2)
    euclideanDistance = math.sqrt(2 * cosineDistance)

    return 1 - cosineDistance

# %%
similarity_score(keypoints[0], keypoints[0]) #should give a score of 1...
# Out:
# 1

# %% [markdown]
# ## define visualisation methods

# %%
#expects a pandas dataframe
def visualize_pose(pose:pd.DataFrame,size = 512):
    canvas =  np.ones(shape=(size,size,3), dtype=np.int16)
    for pair in POSE_PAIRS:
        idFrom = pair[0]
        idTo   = pair[1]
        if pose.iloc[idFrom]['x'] != 0 and pose.iloc[idFrom]['y'] != 0 and pose.iloc[idTo]['x'] != 0 and pose.iloc[idTo]['y'] != 0:
            cv2.line(canvas, (pose.iloc[idFrom]['x'],pose.iloc[idFrom]['y']), (pose.iloc[idTo]['x'],pose.iloc[idTo]['y']), (0, 0, 255), 3)
    plt.imshow(canvas)
    plt.grid(True)

def visualize_poses(pose1:pd.DataFrame,pose2:pd.DataFrame,size = 512):
    canvas =  np.ones(shape=(size,size,3), dtype=np.int16)
    for pair in POSE_PAIRS:
        idFrom = pair[0]
        idTo   = pair[1]
        if pose1.iloc[idFrom]['x'] != 0 and pose1.iloc[idFrom]['y'] != 0 and pose1.iloc[idTo]['x'] != 0 and pose1.iloc[idTo]['y'] != 0:
            cv2.line(canvas, (pose1.iloc[idFrom]['x'],pose1.iloc[idFrom]['y']), (pose1.iloc[idTo]['x'],pose1.iloc[idTo]['y']), (0, 0, 255), 3)
    for pair in POSE_PAIRS:
        idFrom = pair[0]
        idTo   = pair[1]
        if pose2.iloc[idFrom]['x'] != 0 and pose2.iloc[idFrom]['y'] != 0 and pose2.iloc[idTo]['x'] != 0 and pose2.iloc[idTo]['y'] != 0:
            cv2.line(canvas, (pose2.iloc[idFrom]['x'],pose2.iloc[idFrom]['y']), (pose2.iloc[idTo]['x'],pose2.iloc[idTo]['y']), (0, 255, 0), 3)

    plt.imshow(canvas)
    plt.grid(True)


def visualize(pose1:pd.DataFrame,show_image = False,size = 512 ):

    if show_image:
        canvas = cv2.imread(pose1.iloc[0]['path'])
    else:
        canvas =  np.ones(shape=(size,size,3), dtype=np.int16)


    nose =  (pose1.loc["Nose"]['x'],pose1.loc["Nose"]['y'])
    neck =  (pose1.loc["Neck"]['x'],pose1.loc["Neck"]['y'])
    RShoulder =  (pose1.loc["RShoulder"]['x'],pose1.loc["RShoulder"]['y'])
    RElbow =  (pose1.loc["RElbow"]['x'],pose1.loc["RElbow"]['y'])
    RWrist =  (pose1.loc["RWrist"]['x'],pose1.loc["RWrist"]['y'])
    LShoulder =  (pose1.loc["LShoulder"]['x'],pose1.loc["LShoulder"]['y'])
    LElbow =  (pose1.loc["LElbow"]['x'],pose1.loc["LElbow"]['y'])
    LWrist =  (pose1.loc["LWrist"]['x'],pose1.loc["LWrist"]['y'])
    MidHip =  (pose1.loc["MidHip"]['x'],pose1.loc["MidHip"]['y'])
    RHip =  (pose1.loc["RHip"]['x'],pose1.loc["RHip"]['y'])
    RKnee =  (pose1.loc["RKnee"]['x'],pose1.loc["RKnee"]['y'])
    RAnkle =  (pose1.loc["RAnkle"]['x'],pose1.loc["RAnkle"]['y'])
    LHip =  (pose1.loc["LHip"]['x'],pose1.loc["LHip"]['y'])
    LKnee =  (pose1.loc["LKnee"]['x'],pose1.loc["LKnee"]['y'])
    LAnkle =  (pose1.loc["LAnkle"]['x'],pose1.loc["LAnkle"]['y'])
    REye =  (pose1.loc["REye"]['x'],pose1.loc["REye"]['y'])
    LEye =  (pose1.loc["LEye"]['x'],pose1.loc["LEye"]['y'])
    REar =  (pose1.loc["REar"]['x'],pose1.loc["REar"]['y'])
    LEar =  (pose1.loc["LEar"]['x'],pose1.loc["LEar"]['y'])
    LBigToe =  (pose1.loc["LBigToe"]['x'],pose1.loc["LBigToe"]['y'])
    LSmallToe =  (pose1.loc["LSmallToe"]['x'],pose1.loc["LSmallToe"]['y'])
    LHeel =  (pose1.loc["LHeel"]['x'],pose1.loc["LHeel"]['y'])
    RBigToe =  (pose1.loc["RBigToe"]['x'],pose1.loc["RBigToe"]['y'])
    RSmallToe =  (pose1.loc["RSmallToe"]['x'],pose1.loc["RSmallToe"]['y'])
    RHeel =  (pose1.loc["RHeel"]['x'],pose1.loc["RHeel"]['y'])

    if nose != (0,0) and neck != (0,0):
        cv2.line(canvas,nose,neck, (0, 0, 255), 3)
    if REye != (0,0) and nose != (0,0):
        cv2.line(canvas,nose,REye, (0, 0, 255), 3)
    if REye != (0,0) and REar != (0,0):
        cv2.line(canvas,REar,REye, (0, 0, 255), 3)

    if LEye != (0,0) and nose != (0,0):
        cv2.line(canvas,nose,LEye, (0, 0, 255), 3)
    if LEye != (0,0) and LEar != (0,0):
        cv2.line(canvas,LEar,LEye, (0, 0, 255), 3)

    # spine
    if MidHip != (0,0) and neck != (0,0):
        cv2.line(canvas,MidHip,neck, (0, 0, 255), 3)
    if MidHip != (0,0) and RHip != (0,0):
        cv2.line(canvas,MidHip,RHip, (0, 0, 255), 3)
    if MidHip != (0,0) and LHip != (0,0):
        cv2.line(canvas,MidHip,LHip, (0, 0, 255), 3)

    # Right hand
    if RShoulder != (0,0) and neck != (0,0):
        cv2.line(canvas,RShoulder,neck, (0, 0, 255), 3)
    if RElbow != (0,0) and RShoulder != (0,0):
        cv2.line(canvas,RShoulder,RElbow, (0, 0, 255), 3)
    if RWrist != (0,0) and RElbow != (0,0):
        cv2.line(canvas,RWrist,RElbow, (0, 0, 255), 3)


    # Left arm
    if neck != (0,0) and LShoulder != (0,0):
        cv2.line(canvas,LShoulder,neck, (0, 0, 255), 3)
    if LElbow != (0,0) and LShoulder != (0,0):
        cv2.line(canvas,LShoulder,LElbow, (0, 0, 255), 3)
    if LWrist != (0,0) and LElbow != (0,0):
        cv2.line(canvas,LWrist,LElbow, (0, 0, 255), 3)

    #Left leg
    if LKnee != (0,0) and LHip != (0,0):
        cv2.line(canvas,LKnee,LHip, (0, 0, 255), 3)
    if LKnee != (0,0) and LAnkle != (0,0):
        cv2.line(canvas,LKnee,LAnkle, (0, 0, 255), 3)
    if LAnkle != (0,0) and LHeel != (0,0):
        cv2.line(canvas,LHeel,LAnkle, (0, 0, 255), 3)
    if LAnkle != (0,0) and LHeel != (0,0):
        cv2.line(canvas,LBigToe,LAnkle, (0, 0, 255), 3)
    if LAnkle != (0,0) and LHeel != (0,0):
        cv2.line(canvas,LBigToe,LAnkle, (0, 0, 255), 3)
    if LSmallToe != (0,0) and LBigToe != (0,0):
        cv2.line(canvas,LBigToe,LSmallToe, (0, 0, 255), 3)

    # Right leg
    if RKnee != (0,0) and RHip != (0,0):
        cv2.line(canvas,RKnee,RHip, (0, 0, 255), 3)
    if RKnee != (0,0) and RAnkle != (0,0):
        cv2.line(canvas,RKnee,RAnkle, (0, 0, 255), 3)
    if RAnkle != (0,0) and RHeel != (0,0):
        cv2.line(canvas,RHeel,RAnkle, (0, 0, 255), 3)
    if RAnkle != (0,0) and RHeel != (0,0):
        cv2.line(canvas,RBigToe,RAnkle, (0, 0, 255), 3)
    if RAnkle != (0,0) and RHeel != (0,0):
        cv2.line(canvas,RBigToe,RAnkle, (0, 0, 255), 3)
    if RSmallToe != (0,0) and RBigToe != (0,0):
        cv2.line(canvas,RBigToe,RSmallToe, (0, 0, 255), 3)

    if show_image:
        pixels = np.array(cv2.cvtColor(canvas, cv2.COLOR_BGR2RGB))
        plt.imshow(pixels)
    else:
        plt.imshow(canvas)
    plt.grid(True)

# %%
visualize(keypoints[15],True)

# %% [markdown]
# ## Transform & scale

# %%
def scale(pose1, pose2):
    #  Rename columns and concat
    pose1 = pose1.rename(columns={"x":"Xp1", "y":"Yp1", "path":"p1"})
    pose2 = pose2.rename(columns={"x":"Xp2", "y":"Yp2", "path":"p2"})
    pose_df = pd.concat([pose1, pose2],axis = 1)

    # Cropping Pose
    pose_df['Xp1'] = pose_df['Xp1'] - pose_df['Xp1'].min()
    pose_df['Yp1'] = pose_df['Yp1'] - pose_df['Yp1'].min()
    pose_df['Xp2'] = pose_df['Xp2'] - pose_df['Xp2'].min()
    pose_df['Yp2'] = pose_df['Yp2'] - pose_df['Yp2'].min()

    # Resizing Pose
    resize_x = pose_df['Xp2'].max()/pose_df['Xp1'].max()
    resize_y = pose_df['Yp2'].max()/pose_df['Yp1'].max()

    pose_df['Xp1'] = pose_df['Xp1']*resize_x
    pose_df['Yp1'] = pose_df['Yp1']*resize_y

    # print(pose_df)

    # Get dimensions of output window
    max_y = max(pose_df['Yp1'].max(), pose_df['Yp2'].max())
    max_x = max(pose_df['Xp1'].max(), pose_df['Xp2'].max())
    # dim = (int(max_y), int(max_x), 3)



    # Convert DataFrame back to Pose lists
    pose1 = pose_df[['Xp1', 'Yp1', 'p1']]
    x = pose1.rename(columns={"Xp1":"x", "Yp1":"y", "p1":"path"})
    x = x.astype({'x':'int', 'y':'int'})

    pose2 = pose_df[['Xp2','Yp2', 'p2']]
    y = pose2.rename(columns={"Xp2":"x", "Yp2":"y", "p2":"path"})
    y = y.astype({'x':'int', 'y':'int'})

    return x,y
    # return pose1,pose2
# Visualize and Calculate similarity score again
# visualize_output(pose1_new, pose2_new, dim)
# similarity_score(pose1_df, pose2_df)

# %%
# visualize_poses(pandas_keypoints[42],pandas_keypoints[41])
p1,p2 = scale(keypoints[0], keypoints[1])
visualize_poses(p1,p2)

# %% [markdown]
# ## Compare all scores to each other

# %%
similarity_scores = []

for pose1 in keypoints:
    for pose2 in keypoints:
        if pose1 is not pose2:
        #     sp1,sp2 = scale(pose1,pose2)
            score = similarity_score(pose1,pose2)
            similarity_scores.append((score,pose1,pose2))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[218], line 7
#       4 for pose2 in keypoints:
#       5     if pose1 is not pose2:
#       6     #     sp1,sp2 = scale(pose1,pose2)
# ----> 7         score = similarity_score(pose1,pose2)
#       8         similarity_scores.append((score,pose1,pose2))
#
# Cell In[173], line 7, in similarity_score(pose1, pose2)
#       5 # Remove keypoints when keypoint values is none
#       6 pose1_df = pd.DataFrame(pose1, columns=['x','y'])
# ----> 7 pose2_df = pd.DataFrame(pose2, columns=['x','y'])
#       8 # pose_df = pd.concat([pose1, pose2],axis = 1).dropna().reset_index(drop=True)
#       9 # pose1_df = pose1.rename({'x':})
#      10 # pose2_df = pose_df[['Xp2','Yp2']]
#      12 pose1 = pose1_df.to_numpy()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:657, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     654         copy = False
#     656 if isinstance(data, (BlockManager, ArrayManager)):
# --> 657     mgr = self._init_mgr(
#     658         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     659     )
#     661 elif isinstance(data, dict):
#     662     # GH#38939 de facto copy defaults to False only in non-dict cases
#     663     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:290, in NDFrame._init_mgr(cls, mgr, axes, dtype, copy)
#     288         axe = ensure_index(axe)
#     289         bm_axis = cls._get_block_manager_axis(a)
# --> 290         mgr = mgr.reindex_axis(axe, axis=bm_axis)
#     292 # make a copy if explicitly requested
#     293 if copy:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/base.py:98, in DataManager.reindex_axis(self, new_index, axis, fill_value, only_slice)
#      87 @final
#      88 def reindex_axis(
#      89     self: T,
#    (...)
#      93     only_slice: bool = False,
#      94 ) -> T:
#      95     """
#      96     Conform data manager to new index.
#      97     """
# ---> 98     new_index, indexer = self.axes[axis].reindex(new_index)
#     100     return self.reindex_indexer(
#     101         new_index,
#     102         indexer,
#    (...)
#     106         only_slice=only_slice,
#     107     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:4455, in Index.reindex(self, target, method, level, limit, tolerance)
#    4453 else:
#    4454     if self._index_as_unique:
# -> 4455         indexer = self.get_indexer(
#    4456             target, method=method, limit=limit, tolerance=tolerance
#    4457         )
#    4458     elif self._is_multi:
#    4459         raise ValueError("cannot handle a non-unique multi-index!")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3974, in Index.get_indexer(self, target, method, limit, tolerance)
#    3969     target = target.astype(dtype, copy=False)
#    3970     return this._get_indexer(
#    3971         target, method=method, limit=limit, tolerance=tolerance
#    3972     )
# -> 3974 return self._get_indexer(target, method, limit, tolerance)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:4001, in Index._get_indexer(self, target, method, limit, tolerance)
#    3998     else:
#    3999         tgt_values = target._get_engine_target()
# -> 4001     indexer = self._engine.get_indexer(tgt_values)
#    4003 return ensure_platform_int(indexer)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Sort results and display them

# %%
similarity_scores.sort(key=lambda tup: tup[0],reverse=True)
for result in similarity_scores:
    pose1 = result[1]
    pose2 = result[2]

    im1 = cv2.imread(pose1.iloc[0]['path'])
    im2 = cv2.imread(pose2.iloc[0]['path'])
    for i,keypoint in pose1.iterrows():
        x = keypoint['x']
        y = keypoint['y']
        im1 = cv2.circle(im1, (x,y), 3, (0,0,255), -1)

    for i,keypoint in pose2.iterrows():
        x = keypoint['x']
        y = keypoint['y']
        im2 = cv2.circle(im2, (x,y), 3, (0,0,255), -1)

    im2 = cv2.putText(im2, str(result[0]), (0,30), cv2.FONT_HERSHEY_SIMPLEX,
                   1, (0,0,255), 1, 2)

    cv2.imshow("image1",im1)
    cv2.imshow("image2",im2)
    key = cv2.waitKey(0)
    if key == 27: break

    cv2.destroyAllWindows()
cv2.destroyAllWindows()

# %% [markdown]
# ## find best match for a given image

# %%
pose1 = keypoints[654]
similarity_scores = []
for pose2 in keypoints:
    if pose1 is not pose2:
        score = similarity_score(pose1,pose2)
        similarity_scores.append((score,pose1,pose2))

similarity_scores.sort(key=lambda tup: tup[0],reverse=True)
for result in similarity_scores:
    pose1 = result[1]
    pose2 = result[2]

    im1 = cv2.imread(pose1.iloc[0]['path'])
    im2 = cv2.imread(pose2.iloc[0]['path'])
    for i,keypoint in pose1.iterrows():
        x = keypoint['x']
        y = keypoint['y']
        im1 = cv2.circle(im1, (x,y), 3, (0,0,255), -1)

    for i,keypoint in pose2.iterrows():
        x = keypoint['x']
        y = keypoint['y']
        im2 = cv2.circle(im2, (x,y), 3, (0,0,255), -1)

    im2 = cv2.putText(im2, str(result[0]), (0,30), cv2.FONT_HERSHEY_SIMPLEX,
                   1, (0,0,255), 1, 2)

    cv2.imshow("image1",im1)
    cv2.imshow("image2",im2)
    key = cv2.waitKey(0)
    if key == 27: break

    cv2.destroyAllWindows()
cv2.destroyAllWindows()
